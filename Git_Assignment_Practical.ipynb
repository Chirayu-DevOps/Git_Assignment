# %% [markdown]
# Q1. Tasks to be Performed:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q2. Please share command for above point
#
#
# *   $ ls
#
# *   $ mkdir Assignment
#
# *   $ echo "Hello Team PW" Code.txt
#
# *   $ echo "Hello Team PW Skills" Log.txt
#
# *   $ echo "Hello Team DevOps" Output.txt
#
# *   $ git add Code.txt
#
# *   $ git add Output.txt
#
# *   $ git commit -m "Commit Code" Code.txt
#
# *   $ git Commit -m "Output Code" Output.txt
#
# *   $ git remote add origin https://github.com/Chirayu-DevOps/Git_Assignment.git
#
# *   $ git push origin main

# %% [markdown]
# Q3.
#
# 1.   Create a Git working directory with feature1.txt and feature2.txt in the master branch
# 2.   Create 3 branches: develop, feature1, and feature2
# 3.   In develop branch, create develop.txt, do not stage or commit it
# 4.   Stash this file and check out to feature1 branch
# 5.   Create new.txt file in feature1 branch, stage and commit this file
# 6.   Checkout to develop, unstash this file and commit
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# 7. Git Commnads to do above steps
#
# $ git init
#
# $ echo "This is Feature1." > feature1.txt
#
# $ echo "This is Feature2" > feature2.txt
#
# $ git add feature1.txt
#
# $ git add feature2.txt
#
# $ git commit -m "commiting with Feature1.txt and Feature2.txt"
#
# $ git branch develop
#
# $ git branch feature1
#
# $ git branch feature2
#
# $ git checkout develop
#
# $ echo "This is develop branch" > develop.txt
#
# $ git stash --include-untracked
#
# $ git checkout feature1
#
# $ echo "new file in feature1" > new.txt
#
# $ git add new.txt
#
# $ git commit -m "new file in branch feature1"
#
# $ git checkout develop
#
# $ git stash pop
#
# $ git add develop.txt
#
# $ git commit -m "add develop.txt to develope branch"

# %% [markdown]
# Q3.
# 1.   Create a Git working directory with following branches: develop, f1, f2
# 2.   In the Master branch, commit main.txt
# 3.   Put develop.txt in develop branch, f1.txt and f2.txt in f1 and f2 respectively
# 4.   Put all this branch on GitHub
# 5.   On local delete f2 branch
# 6.   Delete the same branch on GitHub as well
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q4.
#
# 1.   Put master.txt on master branch, stage and commit
# ![image.png](data:image/png;base64,...)
#
# 2.   Create 3 branches: public1, public2, private
#
# ![image.png](data:image/png;base64,...)
#
# 3.   Put public1.txt on public1 branch, stage and commit
# ![image.png](data:image/png;base64,...)
#
# 4.   Merge public1 into master
# ![image.png](data:image/png;base64,...)
#
# 5.   Merge public2 into master
# ![image.png](data:image/png;base64,...)
#
# 6.   Edit master.txt on private branch, stage and commit
# ![image.png](data:image/png;base64,...)
#
#
# 7.   Update public1 and public2 with new master code in private
# ![image.png](data:image/png;base64,...)
#
#
# 8.   Also update new master code on master
# ![image.png](data:image/png;base64,...)
#
# 9.   Finally update all code on the private branch
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q5. Tasks to Be Performed:
#
# 1.   Create a Git Flow workflow architecture on Git
# 2.   Create all the required branches
# 3.   starting from e feature branch, push the branch to the master, following the architecture
# 4.    Push an urgent.txt on master using hotfix
# ![Screenshot (100).png](data:image/png;base64,...)![Screenshot (98).png](data:image/png;base64,...)![Screenshot (99).png](data:image/png;base64,...)![Screenshot (96).png](data:image/png;base64,...)![Screenshot (97).png](data:image/png;base64,...)
